# %% [markdown]
# # Project_On
# # IDBM_Movie_Data:

# %% [markdown]
# ## Aim:
#
# ### The aim of the project is to analyze the IDBM_Movie_Data with the following details:

# %% [markdown]
# #### Load the data into your working area and get the information about the null values.

# %% [markdown]
# #### Rename the columns for the analysis purpose if any columns are not in proper way.

# %% [markdown]
# #### Handle the missing value columns with the proper assumtion.

# %% [markdown]
# ####  Generate the relationship between each continuous variable using corr() method.

# %% [markdown]
# ####  Find the movies directed by 'James Gunn', & 'Ridley Scott' with the rating greater than or equal to 8.

# %% [markdown]
# ####  Display all the movies directed by 'Ridley Scott'.

# %% [markdown]
# ####  Display all the director's who got the rating >= 8 for their movies.

# %% [markdown]
# ####  Find all the movies directed by 'James Gunn', & 'Ridley Scott'.

# %% [markdown]
# ####  Display all the movies with the ratings between 8 & 9 and also the films with the highest rating.

# %% [markdown]
# ####  Find the movies directed by both 'Christopher Nolan' and 'Ridley Scott'

# %% [markdown]
# ####  Find all movies that were released between 2006 and 2010, have a rating above 8.0, but made below the 50th percentile in revenue.

# %% [markdown]
# ####  Find all movies that were released between 2006 and 2010, have a rating above 8.0, but made below the 25th percentile in revenue.

# %% [markdown]
# #### Finally give the feedback for all movies with 'Good' if the movie 'rating' is >= 8 and 'Average' if the movie rating doesn't follow the condition given.

# %%
import pandas as pd

# %%
import os

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-d86cfd44b672> in <module>
# ----> 1 os.dir
#
# AttributeError: module 'os' has no attribute 'dir'

# %%
data=pd.read_csv("IMDB_Movie_Data.csv")
data.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %%
data.rename({'Rank':'Score'},axis=1).head(1)
# Out:
#    Score                    Title                    Genre  \
# 0      1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
# sms =pd.isnull(data['population'])
# data[sms]/

# %%
blnk=pd.isnull(data["Revenue (Millions)"])
data[blnk].head(6)
# Out:
#     Rank                    Title                    Genre  \
# 7      8                 Mindhorn                   Comedy
# 22    23           Hounds of Love       Crime,Drama,Horror
# 25    26          Paris pieds nus                   Comedy
# 39    40                5- 25- 77             Comedy,Drama
# 42    43  Don't Fuck in the Woods                   Horror
# 47    48                   Fallen  Adventure,Drama,Fantasy
#
#                                           Description              Director  \
# 7   A has-been actor best known for playing the ti...            Sean Foley
# 22  A cold-blooded predatory couple while cruising...             Ben Young
# 25  Fiona visits Paris for the first time to assis...        Dominique Abel
# 39  Alienated, hopeful-filmmaker Pat Johnson's epi...  Patrick Read Johnson
# 42  A group of friends are going on a camping trip...         Shawn Burkett
# 47  A young girl finds herself in a reform school ...           Scott Hicks
#
# ...

# %%
blnk1=pd.isnull(data["Metascore"])
data[blnk1].head(5)
# Out:
#     Rank                    Title                   Genre  \
# 25    26          Paris pieds nus                  Comedy
# 26    27  Bahubali: The Beginning  Action,Adventure,Drama
# 27    28               Dead Awake         Horror,Thriller
# 39    40                5- 25- 77            Comedy,Drama
# 42    43  Don't Fuck in the Woods                  Horror
#
#                                           Description              Director  \
# 25  Fiona visits Paris for the first time to assis...        Dominique Abel
# 26  In ancient India, an adventurous and daring ma...        S.S. Rajamouli
# 27  A young woman must save herself and her friend...        Phillip Guzman
# 39  Alienated, hopeful-filmmaker Pat Johnson's epi...  Patrick Read Johnson
# 42  A group of friends are going on a camping trip...         Shawn Burkett
#
#                                                Actors  Year  \
# 25  Fiona Gordon, Dominique Abel,Emmanuelle Riva, ...  2016
# ...

# %%
shagun=data["Revenue (Millions)"].ffill(inplace=True)
data.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %%
blnk1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Metascore, Length: 1000, dtype: bool

# %%
blnk1=pd.isnull(data["Metascore"])
data[blnk1].head(3)
# Out:
#     Rank                    Title                   Genre  \
# 25    26          Paris pieds nus                  Comedy
# 26    27  Bahubali: The Beginning  Action,Adventure,Drama
# 27    28               Dead Awake         Horror,Thriller
#
#                                           Description        Director  \
# 25  Fiona visits Paris for the first time to assis...  Dominique Abel
# 26  In ancient India, an adventurous and daring ma...  S.S. Rajamouli
# 27  A young woman must save herself and her friend...  Phillip Guzman
#
#                                                Actors  Year  \
# 25  Fiona Gordon, Dominique Abel,Emmanuelle Riva, ...  2016
# 26  Prabhas, Rana Daggubati, Anushka Shetty,Tamann...  2015
# 27  Jocelin Donahue, Jesse Bradford, Jesse Borrego...  2016
#
#     Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 25                 83     6.8    222              103.14        NaN
# ...

# %%
ar=data["Revenue (Millions)"].ffill(inplace=True)
data.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %%
data.corr()
# Out:
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue (Millions) -0.275981 -0.125763           0.245433  0.184810  0.595916
# Metascore          -0.191869 -0.079305           0.211978  0.631897  0.325684
#
#                     Revenue (Millions)  Metascore
# Rank                         -0.275981  -0.191869
# Year                         -0.125763  -0.079305
# Runtime (Minutes)             0.245433   0.211978
# Rating                        0.184810   0.631897
# Votes                         0.595916   0.325684
# ...

# %%
# data.iloc[Director]('(James) Gunn',axis=0)

# %%
data['Director']
# Out:
# 0                James Gunn
# 1              Ridley Scott
# 2        M. Night Shyamalan
# 3      Christophe Lourdelet
# 4                David Ayer
#                ...
# 995               Billy Ray
# 996                Eli Roth
# 997              Jon M. Chu
# 998          Scot Armstrong
# 999        Barry Sonnenfeld
# Name: Director, Length: 1000, dtype: object

# %%
data.loc[data['Director']=='James Gunn']
# Out:
#      Rank                    Title                    Genre  \
# 0       1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
# 908   909                  Slither     Comedy,Horror,Sci-Fi
# 937   938                    Super             Comedy,Drama
#
#                                            Description    Director  \
# 0    A group of intergalactic criminals are forced ...  James Gunn
# 908  A small town is taken over by an alien plague,...  James Gunn
# 937  After his wife falls under the influence of a ...  James Gunn
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 908  Nathan Fillion, Elizabeth Banks, Michael Rooke...  2006
# 937   Rainn Wilson, Ellen Page, Liv Tyler, Kevin Bacon  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 0                  121     8.1  757074              333.13       76.0
# ...

# %%
data.loc[data['Director']=='Ridley Scott',&'James Gunn']
# Out:
#   File "<ipython-input-38-8b98deba2a13>", line 1
#     data.loc[data['Director']=='Ridley Scott',&'James Gunn']
#                                               ^
# SyntaxError: invalid syntax

# %%
data['Rating']>=8
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Rating, Length: 1000, dtype: bool

# %%
# data.loc['Rating']>=8

# %%
# blnk=pd.isnull(data["Revenue (Millions)"])
# data[blnk].head(6)df.loc[df[‘Price’] >= 10]

# %%
data.loc[data['Rating']>=8].head(3)
# Out:
#     Rank                    Title                    Genre  \
# 0      1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
# 6      7               La La Land       Comedy,Drama,Music
# 16    17            Hacksaw Ridge  Biography,Drama,History
#
#                                           Description         Director  \
# 0   A group of intergalactic criminals are forced ...       James Gunn
# 6   A jazz pianist falls for an aspiring actress i...  Damien Chazelle
# 16  WWII American Army Medic Desmond T. Doss, who ...       Mel Gibson
#
#                                                Actors  Year  \
# 0   Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 6   Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....  2016
# 16  Andrew Garfield, Sam Worthington, Luke Bracey,...  2016
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 0                 121     8.1  757074              333.13       76.0
# ...

# %%
data['Rating'].max()
# Out:
# 9.0

# %%
data.loc[data['Rating']==9]
# Out:
#     Rank            Title               Genre  \
# 54    55  The Dark Knight  Action,Crime,Drama
#
#                                           Description           Director  \
# 54  When the menace known as the Joker wreaks havo...  Christopher Nolan
#
#                                                Actors  Year  \
# 54  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
#
#     Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# 54                152     9.0  1791916              533.32       82.0

# %%
# data.loc["Rating"]==data.loc[data['Director']=='James Gunn']

# %%
data.loc[data['Director']=='Ridley Scott']
# Out:
#      Rank                   Title                     Genre  \
# 1       2              Prometheus  Adventure,Mystery,Sci-Fi
# 102   103             The Martian    Adventure,Drama,Sci-Fi
# 387   388              Robin Hood    Action,Adventure,Drama
# 470   471       American Gangster     Biography,Crime,Drama
# 516   517  Exodus: Gods and Kings    Action,Adventure,Drama
# 521   522           The Counselor      Crime,Drama,Thriller
# 530   531             A Good Year      Comedy,Drama,Romance
# 737   738            Body of Lies      Action,Drama,Romance
#
#                                            Description      Director  \
# 1    Following clues to the origin of mankind, a te...  Ridley Scott
# 102  An astronaut becomes stranded on Mars after hi...  Ridley Scott
# 387  In 12th century England, Robin and his band of...  Ridley Scott
# 470  In 1970s America, a detective works to bring d...  Ridley Scott
# 516  The defiant leader Moses rises up against the ...  Ridley Scott
# ...

# %%
data.nlargest(5,'Rating', keep='last')
# Out:
#      Rank             Title                    Genre  \
# 54     55   The Dark Knight       Action,Crime,Drama
# 117   118            Dangal   Action,Biography,Drama
# 80     81         Inception  Action,Adventure,Sci-Fi
# 249   250  The Intouchables   Biography,Comedy,Drama
# 96     97     Kimi no na wa  Animation,Drama,Fantasy
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 117  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 249  After he becomes a quadriplegic from a paragli...    Olivier Nakache
# 96   Two strangers find themselves linked in a biza...     Makoto Shinkai
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 117  Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016
# ...

# %%
data.loc[data['Director']== 'Christopher Nolan']
# Out:
#      Rank                  Title                    Genre  \
# 36     37           Interstellar   Adventure,Drama,Sci-Fi
# 54     55        The Dark Knight       Action,Crime,Drama
# 64     65           The Prestige     Drama,Mystery,Sci-Fi
# 80     81              Inception  Action,Adventure,Sci-Fi
# 124   125  The Dark Knight Rises          Action,Thriller
#
#                                            Description           Director  \
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 64   Two stage magicians engage in competitive one-...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 124  Eight years after the Joker's reign of anarchy...  Christopher Nolan
#
#                                                 Actors  Year  \
# 36   Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# ...

# %%
stp = data["Year"].between(2006,2010,inclusive = True)
data[stp].head()
# Out:
#     Rank                                     Title                     Genre  \
# 39    40                                 5- 25- 77              Comedy,Drama
# 54    55                           The Dark Knight        Action,Crime,Drama
# 64    65                              The Prestige      Drama,Mystery,Sci-Fi
# 75    76  Pirates of the Caribbean: At World's End  Action,Adventure,Fantasy
# 77    78                      Inglourious Basterds       Adventure,Drama,War
#
#                                           Description              Director  \
# 39  Alienated, hopeful-filmmaker Pat Johnson's epi...  Patrick Read Johnson
# 54  When the menace known as the Joker wreaks havo...     Christopher Nolan
# 64  Two stage magicians engage in competitive one-...     Christopher Nolan
# 75  Captain Barbossa, Will Turner and Elizabeth Sw...        Gore Verbinski
# 77  In Nazi-occupied France during World War II, a...     Quentin Tarantino
#
# ...

# %%
stp = data["Year"].between(2006,2010,inclusive = True,('Rating')==8)
data[stp].head()
# Out:
#   File "<ipython-input-72-c6286c29623c>", line 1
#     stp = data["Year"].between(2006,2010,inclusive = True,('Rating')==8)
#                                                           ^
# SyntaxError: positional argument follows keyword argument
